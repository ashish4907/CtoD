# %%
import pandas as pd

# %%
olympic = pd.read_csv('summer_imp.csv')

# %%
# pd.options.display.max_rows = 100000

# %%
olympic
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31165  2012  London  Wrestling  Wrestling Freestyle
# 31166  2012  London  Wrestling  Wrestling Freestyle
# 31167  2012  London  Wrestling  Wrestling Freestyle
# 31168  2012  London  Wrestling  Wrestling Freestyle
# 31169  2012  London  Wrestling  Wrestling Freestyle
#
#                       Athlete Name Country Gender                       Event  \
# 0                   HAJOS, Alfred      HUN    Men              100M Freestyle
# 1                HERSCHMANN, Otto      AUT    Men              100M Freestyle
# 2               DRIVAS, Dimitrios      GRE    Men  100M Freestyle For Sailors
# ...

# %%
olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31170 entries, 0 to 31169
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          31170 non-null  int64
#  1   City          31170 non-null  object
#  2   Sport         31170 non-null  object
#  3   Discipline    31170 non-null  object
#  4   Athlete Name  31170 non-null  object
#  5   Country       31166 non-null  object
#  6   Gender        31170 non-null  object
#  7   Event         31170 non-null  object
#  8   Medal         31170 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
olympic.Year.value_counts(ascending=True).head()
# Out:
# 1896    151
# 1904    470
# 1900    512
# 1932    615
# 1928    710
# Name: Year, dtype: int64

# %%
olympic.City.value_counts().head()
# Out:
# London         3567
# Athens         2149
# Los Angeles    2074
# Beijing        2043
# Sydney         2015
# Name: City, dtype: int64

# %%
olympic.Sport.value_counts().head()
# Out:
# Aquatics      4170
# Athletics     3639
# Rowing        2668
# Gymnastics    2307
# Fencing       1614
# Name: Sport, dtype: int64

# %%
olympic.Discipline.value_counts().head()
# Out:
# Athletics      3639
# Rowing         2668
# Swimming       2628
# Artistic G.    2103
# Fencing        1614
# Name: Discipline, dtype: int64

# %%
olympic.Athlete Name.value_counts().head()
# Out:
#   File "<ipython-input-10-3ebfa573959a>", line 1
#     olympic.Athlete Name.value_counts().head()
#                     ^
# SyntaxError: invalid syntax

# %%
olympic.rename(columns={"Athlete Name" : "Athlete_Name" },inplace=True)

# %%
olympic.Athlete_Name.value_counts().head()
# Out:
#  PHELPS, Michael        22
#  LATYNINA, Larisa       18
#  ANDRIANOV, Nikolay     15
#  SHAKHLIN, Boris        13
#  ONO, Takashi           13
# Name: Athlete_Name, dtype: int64

# %%
olympic[olympic['Athlete_Name'] == 'JANIKOWSKI, Damian']
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete_Name, Country, Gender, Event, Medal]
# Index: []

# %%
olympic.Athlete_Name=olympic.Athlete_Name.str.strip()

# %%
olympic[olympic['Athlete_Name'] == 'JANIKOWSKI, Damian']
# Out:
#        Year    City      Sport           Discipline        Athlete_Name  \
# 31165  2012  London  Wrestling  Wrestling Freestyle  JANIKOWSKI, Damian
#
#       Country Gender     Event   Medal
# 31165     POL    Men  Wg 84 KG  Bronze

# %%
olympic.Country.value_counts(dropna=False)
# Out:
# USA    4585
# URS    2049
# GBR    1720
# FRA    1396
# GER    1305
# ITA    1296
# AUS    1189
# HUN    1079
# SWE    1044
# NED     851
# GDR     825
# CHN     806
# JPN     788
# RUS     768
# CAN     649
# ROU     640
# NOR     554
# KOR     529
# POL     511
# DEN     507
# FRG     490
# FIN     456
# ESP     442
# YUG     435
# BRA     431
# BEL     411
# CUB     410
# SUI     380
# BUL     333
# TCH     329
# EUA     260
# ARG     259
# EUN     223
# NZL     190
# IND     183
# UKR     173
# GRE     148
# AUT     146
# JAM     127
# PAK     121
# CRO     114
# BLR     113
# MEX     106
# RSA     106
# KEN      93
# TUR      86
# NGR      84
# URU      76
# IRI      61
# PRK      58
# CZE      56
# LTU      55
# KAZ      49
# ZZX      48
# ETH      45
# TPE      44
# EST      39
# INA      38
# SVK      34
# POR      33
# CHI      33
# SRB      31
# IRL      30
# ANZ      29
# EGY      28
# BAH      27
# SLO      26
# AZE      26
# GEO      25
# THA      25
# MGL      24
# ...

# %%
olympic.Country.isnull().sum()
# Out:
# 4

# %%
olympic.Country.shape
# Out:
# (31170,)

# %%
olympic.dropna(inplace=True)

# %%
olympic.Country.shape
# Out:
# (31166,)

# %%
olympic.Gender.value_counts().head()
# Out:
# Men      22749
# Women     8417
# Name: Gender, dtype: int64

# %%
olympic.Event.value_counts().head()
# Out:
# Football            1497
# Hockey              1422
# Team Competition    1147
# Basketball          1012
# Handball             973
# Name: Event, dtype: int64

# %%
olympic.Medal.value_counts().head()
# Out:
# Gold          10481
# Bronze        10372
# Silver        10309
# Gold Medal        4
# Name: Medal, dtype: int64

# %%
olympic.Medal.replace(to_replace='Gold Medal',value='Gold',inplace=True)

# %%
olympic.Medal.value_counts().head()
# Out:
# Gold      10485
# Bronze    10372
# Silver    10309
# Name: Medal, dtype: int64

# %%
olympic.isnull().sum()
# Out:
# Year            0
# City            0
# Sport           0
# Discipline      0
# Athlete_Name    0
# Country         0
# Gender          0
# Event           0
# Medal           0
# dtype: int64

# %%
olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31166 entries, 0 to 31169
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          31166 non-null  int64
#  1   City          31166 non-null  object
#  2   Sport         31166 non-null  object
#  3   Discipline    31166 non-null  object
#  4   Athlete_Name  31166 non-null  object
#  5   Country       31166 non-null  object
#  6   Gender        31166 non-null  object
#  7   Event         31166 non-null  object
#  8   Medal         31166 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.4+ MB

# %%
olympic.describe()
# Out:
#                Year
# count  31166.000000
# mean    1970.477828
# std       33.157245
# min     1896.000000
# 25%     1948.000000
# 50%     1980.000000
# 75%     2000.000000
# max     2012.000000

# %%
olympic[olympic.duplicated(keep='first')]
# Out:
#        Year       City      Sport Discipline           Athlete_Name Country  \
# 2069   1912  Stockholm  Athletics  Athletics  LELONG, Charles Louis     FRA
# 12253  1968     Mexico    Fencing    Fencing          KALMAR, Janos     HUN
# 15596  1980     Moscow     Boxing     Boxing       MUSTAFOV, Ismail     BUL
# 16102  1980     Moscow     Hockey     Hockey           SINGH, Singh     IND
# 21833  1996    Atlanta   Baseball   Baseball         SCULL, Antonio     CUB
# 28678  2008    Beijing     Rowing     Rowing      VOLPENHEIN, Bryan     USA
# 29790  2012     London  Badminton  Badminton           ZHAO, Yunlei     CHN
#
#       Gender                     Event   Medal
# 2069     Men              4X400M Relay  Silver
# 12253    Men                Sabre Team  Bronze
# 15596    Men  - 48KG (Light-Flyweight)  Bronze
# 16102    Men                    Hockey    Gold
# 21833    Men                  Baseball    Gold
# 28678    Men  Eight With Coxswain (8+)  Bronze
# ...

# %%
olympic.drop_duplicates(keep='first',inplace=True)

# %%
olympic[olympic.duplicated(keep='first')]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete_Name, Country, Gender, Event, Medal]
# Index: []

# %%
olympic.shape
# Out:
# (31159, 9)

# %%
olympic.count()
# Out:
# Year            31159
# City            31159
# Sport           31159
# Discipline      31159
# Athlete_Name    31159
# Country         31159
# Gender          31159
# Event           31159
# Medal           31159
# dtype: int64

# %% [markdown]
# ## Data Analysis

# %%
pd.options.display.max_rows = 2000

# %%
olympic.head(2)
# Out:
#    Year    City     Sport Discipline      Athlete_Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming     HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming  HERSCHMANN, Otto     AUT    Men
#
#             Event   Medal
# 0  100M Freestyle    Gold
# 1  100M Freestyle  Silver

# %%
olympic[olympic.iloc[:,0]== 2012]
# Out:
#        Year    City              Sport             Discipline  \
# 29221  2012  London           Aquatics                 Diving
# 29222  2012  London           Aquatics                 Diving
# 29223  2012  London           Aquatics                 Diving
# 29224  2012  London           Aquatics                 Diving
# 29225  2012  London           Aquatics                 Diving
# 29226  2012  London           Aquatics                 Diving
# 29227  2012  London           Aquatics                 Diving
# 29228  2012  London           Aquatics                 Diving
# 29229  2012  London           Aquatics                 Diving
# 29230  2012  London           Aquatics                 Diving
# 29231  2012  London           Aquatics                 Diving
# 29232  2012  London           Aquatics                 Diving
# 29233  2012  London           Aquatics                 Diving
# 29234  2012  London           Aquatics                 Diving
# ...

# %%
olympic.head(2)
# Out:
#    Year    City     Sport Discipline      Athlete_Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming     HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming  HERSCHMANN, Otto     AUT    Men
#
#             Event   Medal
# 0  100M Freestyle    Gold
# 1  100M Freestyle  Silver

# %%
olympic[(olympic.iloc[:,0]==2012) & (olympic.iloc[:,8] == 'Gold') &(olympic.iloc[:,6] == 'Men') &(olympic.iloc[:,5]=='USA')].head()
# Out:
#        Year    City     Sport Discipline      Athlete_Name Country Gender  \
# 29221  2012  London  Aquatics     Diving     BOUDIA, David     USA    Men
# 29263  2012  London  Aquatics   Swimming  GREVERS, Matthew     USA    Men
# 29275  2012  London  Aquatics   Swimming   PHELPS, Michael     USA    Men
# 29281  2012  London  Aquatics   Swimming    ADRIAN, Nathan     USA    Men
# 29290  2012  London  Aquatics   Swimming      CLARY, Tyler     USA    Men
#
#                  Event Medal
# 29221     10M Platform  Gold
# 29263  100M Backstroke  Gold
# 29275   100M Butterfly  Gold
# 29281   100M Freestyle  Gold
# 29290  200M Backstroke  Gold

# %%
olympic.iloc[:,1].unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney',
#        'Beijing'], dtype=object)

# %%
berlin=olympic[(olympic.iloc[:,1]=='Berlin') & (olympic.iloc[:,6]=='Women') &(olympic.iloc[:,8] =='Bronze')]

# %%
berlin
# Out:
#       Year    City       Sport   Discipline  \
# 6333  1936  Berlin    Aquatics       Diving
# 6339  1936  Berlin    Aquatics       Diving
# 6345  1936  Berlin    Aquatics     Swimming
# 6351  1936  Berlin    Aquatics     Swimming
# 6360  1936  Berlin    Aquatics     Swimming
# 6366  1936  Berlin    Aquatics     Swimming
# 6369  1936  Berlin    Aquatics     Swimming
# 6370  1936  Berlin    Aquatics     Swimming
# 6371  1936  Berlin    Aquatics     Swimming
# 6372  1936  Berlin    Aquatics     Swimming
# 6430  1936  Berlin   Athletics    Athletics
# 6463  1936  Berlin   Athletics    Athletics
# 6464  1936  Berlin   Athletics    Athletics
# 6465  1936  Berlin   Athletics    Athletics
# 6466  1936  Berlin   Athletics    Athletics
# 6496  1936  Berlin   Athletics    Athletics
# 6505  1936  Berlin   Athletics    Athletics
# 6514  1936  Berlin   Athletics    Athletics
# 6520  1936  Berlin   Athletics    Athletics
# 6737  1936  Berlin     Fencing      Fencing
# ...

# %%
berlin[(berlin.iloc[:,5]=='USA') & (berlin.iloc[:,3] == 'Swimming') & (berlin.iloc[:,7] =="4X100M Freestyle Relay")]
# Out:
#       Year    City     Sport Discipline             Athlete_Name Country  \
# 6369  1936  Berlin  Aquatics   Swimming      FREEMAN, Mavis Anne     USA
# 6370  1936  Berlin  Aquatics   Swimming       LAPP, Bernice Ruth     USA
# 6371  1936  Berlin  Aquatics   Swimming       MCKEAN, Mary Olive     USA
# 6372  1936  Berlin  Aquatics   Swimming  RAWLS, Katherine Louise     USA
#
#      Gender                   Event   Medal
# 6369  Women  4X100M Freestyle Relay  Bronze
# 6370  Women  4X100M Freestyle Relay  Bronze
# 6371  Women  4X100M Freestyle Relay  Bronze
# 6372  Women  4X100M Freestyle Relay  Bronze

# %%
berlin.Sport.value_counts()
# Out:
# Aquatics      10
# Athletics      9
# Gymnastics     8
# Fencing        1
# Name: Sport, dtype: int64

# %%
berlin.Country.value_counts()
# Out:
# HUN    8
# USA    7
# GER    5
# CAN    5
# POL    1
# AUT    1
# DEN    1
# Name: Country, dtype: int64

# %%
olympic[(olympic.iloc[:,2]== 'Fencing') & (olympic.iloc[:,5] == 'USA')]
# Out:
#        Year         City    Sport Discipline                Athlete_Name  \
# 867    1904     St Louis  Fencing    Fencing                 FOX, Arthur
# 868    1904     St Louis  Fencing    Fencing             TATHAM, Charles
# 869    1904     St Louis  Fencing    Fencing  TOWNSEND, Charles Fitzhugh
# 872    1904     St Louis  Fencing    Fencing              GREBE, William
# 873    1904     St Louis  Fencing    Fencing              GREBE, William
# 875    1904     St Louis  Fencing    Fencing     O'CONNOR, William Scott
# 3244   1920      Antwerp  Fencing    Fencing  BRECKINRIDGE, Henry Cabell
# 3245   1920      Antwerp  Fencing    Fencing  HONEYCUTT, Francis Webster
# 3246   1920      Antwerp  Fencing    Fencing       LYON, Arthur St Clair
# 3247   1920      Antwerp  Fencing    Fencing              RAYNER, Harold
# 3248   1920      Antwerp  Fencing    Fencing               SEARS, Robert
# 5300   1928    Amsterdam  Fencing    Fencing      CALNAN, George Charles
# ...

# %%
olympic.head(2)
# Out:
#    Year    City     Sport Discipline      Athlete_Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming     HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming  HERSCHMANN, Otto     AUT    Men
#
#             Event   Medal
# 0  100M Freestyle    Gold
# 1  100M Freestyle  Silver
