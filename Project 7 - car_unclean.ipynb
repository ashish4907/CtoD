# %%
import pandas as pd

# %%
car = pd.read_csv('cars_unclean.csv')

# %%
pd.options.display.max_rows = 400

# %%
car
# Out:
#            mpg  cylinders  displacement        horsepower  weight  \
# 0    18.000000          8         307.0          130.0 hp    3504
# 1    15.000000          8         350.0          165.0 hp    3693
# 2    18.000000          8         318.0          150.0 hp    3436
# 3    16.000000          8         304.0          150.0 hp    3433
# 4    17.000000          8         302.0          140.0 hp    3449
# 5    15.000000          8         429.0          198.0 hp    4341
# 6    14.000000          8         454.0          220.0 hp    4354
# 7    14.000000          8         440.0          215.0 hp    4312
# 8    14.000000          8         455.0          225.0 hp    4425
# 9    15.000000          8         390.0          190.0 hp    3850
# 10   15.000000          8         383.0          170.0 hp    3563
# 11   14.000000          8         340.0          160.0 hp    3609
# 12   15.000000          8         400.0          150.0 hp    3761
# ...

# %%
car.shape
# Out:
# (329, 9)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           329 non-null    float64
#  1   cylinders     329 non-null    int64
#  2   displacement  329 non-null    float64
#  3   horsepower    329 non-null    object
#  4   weight        329 non-null    int64
#  5   acceleration  329 non-null    float64
#  6   model year    329 non-null    int64
#  7   origin        329 non-null    object
#  8   name          329 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 23.3+ KB

# %%
car.describe()
# Out:
#               mpg   cylinders  displacement        weight  acceleration  \
# count  329.000000  329.000000    329.000000    329.000000    329.000000
# mean    21.655199    5.802432    217.004559   3229.082067     15.400000
# std      7.294651    1.719825    104.719009   1376.306985      2.922756
# min      0.060606    4.000000     68.000000   1800.000000      8.000000
# 25%     16.000000    4.000000    121.000000   2464.000000     13.500000
# 50%     20.200000    6.000000    200.000000   3102.000000     15.400000
# 75%     26.000000    8.000000    305.000000   3821.000000     17.000000
# max     44.300000    8.000000    455.000000  23000.000000     24.800000
#
#         model year
# count   329.000000
# mean    104.495441
# std     232.498690
# min      70.000000
# 25%      73.000000
# 50%      76.000000
# 75%      79.000000
# max    1973.000000

# %%
car.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# name            0
# dtype: int64

# %%
car.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0   130.0 hp    3504          12.0          70
# 1  15.0          8         350.0   165.0 hp    3693          11.5          70
#
#           origin                          name
# 0  United States    chevrolet chevelle malibu
# 1  United States            buick skylark 320

# %% [markdown]
# ## mpg

# %%
car.mpg.value_counts(dropna=False).head(2)
# Out:
# 13.0    21
# 14.0    20
# Name: mpg, dtype: int64

# %%
print(car['mpg'].dtype)
# Out:
# float64

# %%
car.iloc[:,0].isnull().sum()
# Out:
# 0

# %%
car.loc[car.mpg.idxmin(),"mpg"]
# Out:
# 0.060606061

# %%
car[car['mpg'] == 0.060606061]
# Out:
#           mpg  cylinders  displacement horsepower  weight  acceleration  \
# 244  0.060606          8         351.0   138.0 hp    3955          13.2
#
#      model year origin                      name
# 244          79    usa    mercury grand marquis

# %%
car.mpg.mean()
# Out:
# 21.655199410519753

# %%
mean=round(car.mpg.mean(),1)

# %%
mean
# Out:
# 21.7

# %%
car['mpg'].replace(to_replace=0.060606061,value=mean,inplace=True)

# %%
car.iloc[244]
# Out:
# mpg                                 21.7
# cylinders                              8
# displacement                       351.0
# horsepower                      138.0 hp
# weight                              3955
# acceleration                        13.2
# model year                            79
# origin                               usa
# name              mercury grand marquis
# Name: 244, dtype: object

# %%
car[car['mpg'] == 14].head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 6  14.0          8         454.0   220.0 hp    4354           9.0          70
# 7  14.0          8         440.0   215.0 hp    4312           8.5          70
#
#   origin                  name
# 6    usa     chevrolet impala
# 7    usa    plymouth fury iii

# %%
car.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0   130.0 hp    3504          12.0          70
# 1  15.0          8         350.0   165.0 hp    3693          11.5          70
#
#           origin                          name
# 0  United States    chevrolet chevelle malibu
# 1  United States            buick skylark 320

# %% [markdown]
# ## cylinders

# %%
car.cylinders.value_counts(dropna=False)
# Out:
# 4    138
# 8    107
# 6     81
# 5      3
# Name: cylinders, dtype: int64

# %%
138+107+81+3
# Out:
# 329

# %%
print(car['cylinders'].dtype)
# Out:
# int64

# %%
car.iloc[:,1].isnull().sum()
# Out:
# 0

# %%
car[car['cylinders'] == 5]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 232  20.3          5         131.0   103.0 hp    2830          15.9
# 253  25.4          5         183.0    77.0 hp    3530          20.1
# 274  36.4          5         121.0    67.0 hp    2950          19.9
#
#      model year  origin                    name
# 232          78  europe              audi 5000
# 253          79  europe     mercedes-benz 300d
# 274          80  europe    audi 5000s (diesel)

# %%
car.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0   130.0 hp    3504          12.0          70
# 1  15.0          8         350.0   165.0 hp    3693          11.5          70
#
#           origin                          name
# 0  United States    chevrolet chevelle malibu
# 1  United States            buick skylark 320

# %% [markdown]
# ### displacement

# %%
car.displacement.value_counts(dropna=False).head(2)
# Out:
# 350.0    18
# 250.0    18
# Name: displacement, dtype: int64

# %%
print(car['displacement'].dtype)
# Out:
# float64

# %%
car.iloc[:,2].isnull().sum()
# Out:
# 0

# %%
car[car['displacement'] > 100].mean()
# Out:
# mpg               19.978417
# cylinders          6.133094
# displacement     239.805755
# weight          3368.866906
# acceleration      15.061871
# model year       109.679856
# dtype: float64

# %%
car.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0   130.0 hp    3504          12.0          70
# 1  15.0          8         350.0   165.0 hp    3693          11.5          70
#
#           origin                          name
# 0  United States    chevrolet chevelle malibu
# 1  United States            buick skylark 320

# %% [markdown]
# ### horsepower

# %%
car.horsepower.value_counts(dropna=False).head(2)
# Out:
# 150.0 hp    22
# 90.0 hp     19
# Name: horsepower, dtype: int64

# %%
print(car['horsepower'].dtype)
# Out:
# object

# %%
car[car['horsepower'] == 'Not available hp']
# Out:
#       mpg  cylinders  displacement        horsepower  weight  acceleration  \
# 28   25.0          4          98.0  Not available hp    2046          19.0
# 111  21.0          6         200.0  Not available hp    2875          17.0
# 276  40.9          4          85.0  Not available hp    1835          17.3
# 279  23.6          4         140.0  Not available hp    2905          14.3
# 290  34.5          4         100.0  Not available hp    2320          15.8
# 304  23.0          4         151.0  Not available hp    3035          20.5
#
#      model year  origin                     name
# 28           71     usa              ford pinto
# 111          74     usa           ford maverick
# 276          80  europe    renault lecar deluxe
# 279          80     usa      ford mustang cobra
# 290          81  europe             renault 18i
# 304          82     usa          amc concord dl

# %%
import numpy as np

# %%
car['horsepower'].replace(to_replace='Not available hp',value=np.nan,inplace=True)

# %%
car.iloc[:,3].isnull().sum()
# Out:
# 6

# %%
# car.iloc[25:30]

# %%
car.horsepower.fillna(method='ffill',inplace=True)

# %%
# car.iloc[104:113]

# %%
car.iloc[:,3].isnull().sum()
# Out:
# 0

# %%
car['horsepower'] = car['horsepower'].str.replace(" hp","")

# %%
car.head(1)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0    3504          12.0          70
#
#           origin                          name
# 0  United States    chevrolet chevelle malibu

# %%
print(car['horsepower'].dtype)
# Out:
# object

# %%
car['horsepower']= car['horsepower'].astype('float')

# %%
car[car['horsepower']== 90].head(2)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 19  24.0          4         107.0        90.0    2430          14.5
# 22  21.0          6         199.0        90.0    2648          15.0
#
#     model year  origin            name
# 19          70  europe    audi 100 ls
# 22          70     usa    amc gremlin

# %%
car.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model year         origin                          name
# 0          70  United States    chevrolet chevelle malibu
# 1          70  United States            buick skylark 320

# %% [markdown]
# ### weight

# %%
car.weight.value_counts().head()
# Out:
# 2945    4
# 2125    3
# 4215    3
# 4654    2
# 2164    2
# Name: weight, dtype: int64

# %%
print(car['weight'].dtype)
# Out:
# int64

# %%
car.iloc[:,4].isnull().sum()
# Out:
# 0

# %%
car[car['weight']> 8000]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 126  26.0          4          97.0        78.0   23000          14.5
#
#      model year  origin           name
# 126          74  europe    opel manta

# %%
 car['weight'].replace(to_replace=23000,value=2300,inplace=True)

# %%
car.iloc[126]
# Out:
# mpg                      26.0
# cylinders                   4
# displacement             97.0
# horsepower               78.0
# weight                   2300
# acceleration             14.5
# model year                 74
# origin                 europe
# name              opel manta
# Name: 126, dtype: object

# %%
car[car['weight'] == 2300]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 126  26.0          4          97.0        78.0    2300          14.5
# 189  25.5          4         122.0        96.0    2300          15.5
#
#      model year  origin                  name
# 126          74  europe           opel manta
# 189          77     usa    plymouth arrow gs

# %%
car.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model year         origin                          name
# 0          70  United States    chevrolet chevelle malibu
# 1          70  United States            buick skylark 320

# %% [markdown]
# ### acceleration

# %%
car.acceleration.value_counts(dropna=False).head(1)
# Out:
# 15.5    18
# Name: acceleration, dtype: int64

# %%
print(car['acceleration'].dtype)
# Out:
# float64

# %%
car.iloc[:,5].isnull().sum()
# Out:
# 0

# %%
car[car['acceleration'] == 13.4]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 225  17.7          6         231.0       165.0    3445          13.4
# 243  17.6          8         302.0       129.0    3725          13.4
#
#      model year origin                                name
# 225          78    usa    buick regal sport coupe (turbo)
# 243          79    usa                    ford ltd landau

# %%
car.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model year         origin                          name
# 0          70  United States    chevrolet chevelle malibu
# 1          70  United States            buick skylark 320

# %% [markdown]
# ### model year

# %%
car.rename(columns={"model year" : "model_year"},inplace=True )

# %%
car.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year         origin                          name
# 0          70  United States    chevrolet chevelle malibu
# 1          70  United States            buick skylark 320

# %%
car.model_year.value_counts(dropna=False)
# Out:
# 73      33
# 76      32
# 70      29
# 78      28
# 79      27
# 75      26
# 71      25
# 72      23
# 82      23
# 74      22
# 77      22
# 80      17
# 81      17
# 1973     5
# Name: model_year, dtype: int64

# %%
print(car['model_year'].dtype)
# Out:
# int64

# %%
car['model_year'].replace(to_replace=1973,value=73,inplace=True)

# %%
car.model_year.value_counts()
# Out:
# 73    38
# 76    32
# 70    29
# 78    28
# 79    27
# 75    26
# 71    25
# 72    23
# 82    23
# 74    22
# 77    22
# 80    17
# 81    17
# Name: model_year, dtype: int64

# %%
car['model_year'].unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], dtype=int64)

# %%
print(car['model_year'].dtype)
# Out:
# int64

# %%
car.iloc[:,6].isnull().sum()
# Out:
# 0

# %%
car[car['model_year']== 70].head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year         origin                          name
# 0          70  United States    chevrolet chevelle malibu
# 1          70  United States            buick skylark 320

# %%
car.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year         origin                          name
# 0          70  United States    chevrolet chevelle malibu
# 1          70  United States            buick skylark 320

# %% [markdown]
# ### origin

# %%
car.origin.value_counts()
# Out:
# usa              254
# europe            72
# United States      3
# Name: origin, dtype: int64

# %%
car['origin'].replace(to_replace='United States',value='usa',inplace=True)

# %%
car.origin.value_counts()
# Out:
# usa       257
# europe     72
# Name: origin, dtype: int64

# %%
print(car['origin'].dtype)
# Out:
# object

# %%
car.iloc[:,7].isnull().sum()
# Out:
# 0

# %%
car[car['origin'] == 'europe'].head(2)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 17  26.0          4          97.0        46.0    1835          20.5
# 18  25.0          4         110.0        87.0    2672          17.5
#
#     model_year  origin                     name
# 17          70  europe    vw 1131 deluxe sedan
# 18          70  europe             peugeot 504

# %%
car.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year origin                          name
# 0          70    usa    chevrolet chevelle malibu
# 1          70    usa            buick skylark 320

# %% [markdown]
# ## name

# %%
car.name.value_counts(dropna=False).head(2)
# Out:
#   amc matador     6
#   ford pinto      6
# Name: name, dtype: int64

# %%
print(car['name'].dtype)
# Out:
# object

# %%
car.iloc[:,8].isnull().sum()
# Out:
# 0

# %%
car[car['name'] == 'ford pinto']
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model_year, origin, name]
# Index: []

# %%
car.name=car.name.str.strip()

# %%
car[car['name'] == 'ford pinto']
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28   25.0          4          98.0        90.0    2046          19.0
# 98   19.0          4         122.0        85.0    2310          18.5
# 114  26.0          4         122.0        80.0    2451          16.5
# 146  23.0          4         140.0        83.0    2639          17.0
# 150  18.0          6         171.0        97.0    2984          14.5
# 178  26.5          4         140.0        72.0    2565          13.6
#
#      model_year origin        name
# 28           71    usa  ford pinto
# 98           73    usa  ford pinto
# 114          74    usa  ford pinto
# 146          75    usa  ford pinto
# 150          75    usa  ford pinto
# 178          76    usa  ford pinto

# %%
car.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320

# %% [markdown]
# ### Duplicates

# %%
car.loc[car.duplicated(keep=False)].sort_values('name')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 323  24.3          4         151.0        90.0    3003          20.1
# 268  24.3          4         151.0        90.0    3003          20.1
# 322  16.0          6         258.0       110.0    3632          18.0
# 117  16.0          6         258.0       110.0    3632          18.0
# 308  25.0          6         181.0       110.0    2945          16.4
# 328  25.0          6         181.0       110.0    2945          16.4
# 31   17.0          6         250.0       100.0    3329          15.5
# 326  17.0          6         250.0       100.0    3329          15.5
# 165  14.5          8         351.0       152.0    4215          12.8
# 327  14.5          8         351.0       152.0    4215          12.8
# 79   12.0          8         429.0       198.0    4952          11.5
# 324  12.0          8         429.0       198.0    4952          11.5
# 320  14.0          8         340.0       160.0    3609           8.0
# ...

# %%
car.drop_duplicates(keep='first',inplace=True)

# %%
car[car.duplicated(keep='first')]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model_year, origin, name]
# Index: []

# %% [markdown]
# ### Data Analytics

# %%
car.shape
# Out:
# (319, 9)

# %%
car.count()
# Out:
# mpg             319
# cylinders       319
# displacement    319
# horsepower      319
# weight          319
# acceleration    319
# model_year      319
# origin          319
# name            319
# dtype: int64

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 319 entries, 0 to 318
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           319 non-null    float64
#  1   cylinders     319 non-null    int64
#  2   displacement  319 non-null    float64
#  3   horsepower    319 non-null    float64
#  4   weight        319 non-null    int64
#  5   acceleration  319 non-null    float64
#  6   model_year    319 non-null    int64
#  7   origin        319 non-null    object
#  8   name          319 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 24.9+ KB

# %%
car.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  319.000000  319.000000    319.000000  319.000000   319.000000
# mean    21.813166    5.789969    215.891850  110.191223  3155.962382
# std      7.222803    1.720143    104.360203   39.620898   834.343834
# min      9.000000    4.000000     68.000000   46.000000  1800.000000
# 25%     16.000000    4.000000    121.000000   83.000000  2440.500000
# 50%     20.500000    6.000000    200.000000   98.000000  3085.000000
# 75%     26.450000    8.000000    304.500000  140.000000  3802.500000
# max     44.300000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    319.000000  319.000000
# mean      15.418495   75.655172
# std        2.905785    3.628187
# min        8.000000   70.000000
# 25%       13.500000   73.000000
# 50%       15.400000   76.000000
# 75%       17.000000   79.000000
# max       24.800000   82.000000

# %%
m_year=list(car.groupby(by=['model_year','origin']))

# %%
len(m_year)
# Out:
# 26

# %%
m_year[0][1]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 17  26.0          4          97.0        46.0    1835          20.5
# 18  25.0          4         110.0        87.0    2672          17.5
# 19  24.0          4         107.0        90.0    2430          14.5
# 20  25.0          4         104.0        95.0    2375          17.5
# 21  26.0          4         121.0       113.0    2234          12.5
#
#     model_year  origin                  name
# 17          70  europe  vw 1131 deluxe sedan
# 18          70  europe           peugeot 504
# 19          70  europe           audi 100 ls
# 20          70  europe              saab 99e
# 21          70  europe              bmw 2002

# %%
cylinders= car.groupby('model_year').cylinders.count()

# %%
cylinders
# Out:
# model_year
# 70    27
# 71    24
# 72    23
# 73    36
# 74    21
# 75    26
# 76    30
# 77    22
# 78    28
# 79    27
# 80    16
# 81    17
# 82    22
# Name: cylinders, dtype: int64

# %%
# %matplotlib  inline
import matplotlib.pyplot as plt
plt.style.use('seaborn')
cylinders.plot(kind='bar',figsize=(14,8),fontsize=14)
plt.show()
