# %%
import pandas as pd

# %%
police= pd.read_csv('PoliceData.csv')

# %%
police.shape
# Out:
# (65535, 15)

# %%
police.head(2)
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
#
#    driver_age driver_race violation_raw violation  search_conducted  \
# 0        20.0       White      Speeding  Speeding             False
# 1        40.0       White      Speeding  Speeding             False
#
#   search_type stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN     Citation       False      0-15 Min               False
# 1         NaN     Citation       False      0-15 Min               False

# %%
police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65535 non-null  object
#  1   stop_time           65535 non-null  object
#  2   country_name        0 non-null      float64
#  3   driver_gender       61474 non-null  object
#  4   driver_age_raw      61481 non-null  float64
#  5   driver_age          61228 non-null  float64
#  6   driver_race         61475 non-null  object
#  7   violation_raw       61475 non-null  object
#  8   violation           61475 non-null  object
#  9   search_conducted    65535 non-null  bool
#  10  search_type         2479 non-null   object
#  11  stop_outcome        61475 non-null  object
#  12  is_arrested         61475 non-null  object
#  13  stop_duration       61475 non-null  object
#  14  drugs_related_stop  65535 non-null  bool
# ...

# %%
police.describe()
# Out:
#        country_name  driver_age_raw    driver_age
# count           0.0    61481.000000  61228.000000
# mean            NaN     1967.791106     34.148984
# std             NaN      121.050106     12.760710
# min             NaN        0.000000     15.000000
# 25%             NaN     1965.000000     23.000000
# 50%             NaN     1978.000000     31.000000
# 75%             NaN     1985.000000     43.000000
# max             NaN     8801.000000     88.000000

# %%
police.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
police.stop_date.value_counts()
# Out:
# 1/11/2012    69
# 2/28/2012    65
# 5/16/2007    62
# 1/2/2012     61
# 1/10/2007    60
#              ..
# 9/3/2005      1
# 9/29/2005     1
# 9/17/2005     1
# 7/28/2005     1
# 4/1/2005      1
# Name: stop_date, Length: 2651, dtype: int64

# %% [markdown]
# ### stop_date

# %%
print(police['stop_date'].dtype)
# Out:
# object

# %%
police['stop_date'] = pd.to_datetime(police['stop_date'])

# %%
print(police['stop_date'].dtype)
# Out:
# datetime64[ns]

# %%
police.head(2)
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0 2005-01-02      1:55           NaN             M          1985.0
# 1 2005-01-18      8:15           NaN             M          1965.0
#
#    driver_age driver_race violation_raw violation  search_conducted  \
# 0        20.0       White      Speeding  Speeding             False
# 1        40.0       White      Speeding  Speeding             False
#
#   search_type stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN     Citation       False      0-15 Min               False
# 1         NaN     Citation       False      0-15 Min               False

# %% [markdown]
# ### stop_time

# %%
print(police['stop_time'].dtype)
# Out:
# object

# %%
police.stop_time.value_counts()
# Out:
# 10:00    280
# 11:00    280
# 9:00     252
# 10:30    251
# 9:30     246
#         ...
# 5:27       1
# 5:38       1
# 5:08       1
# 5:09       1
# 4:48       1
# Name: stop_time, Length: 1432, dtype: int64

# %%
police[police['stop_time']=='10:00'].head(2)
# Out:
#      stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 4   2005-03-14     10:00           NaN             F          1984.0
# 148 2005-10-05     10:00           NaN             M          1981.0
#
#      driver_age driver_race violation_raw violation  search_conducted  \
# 4          21.0       White      Speeding  Speeding             False
# 148        24.0       White      Speeding  Speeding             False
#
#     search_type stop_outcome is_arrested stop_duration  drugs_related_stop
# 4           NaN     Citation       False      0-15 Min               False
# 148         NaN     Citation       False      0-15 Min               False

# %%
police.iloc[:,1]
# Out:
# 0         1:55
# 1         8:15
# 2        23:15
# 3        17:15
# 4        10:00
#          ...
# 65530    17:54
# 65531    22:22
# 65532    23:20
# 65533     0:23
# 65534     0:30
# Name: stop_time, Length: 65535, dtype: object

# %% [markdown]
# ### country_name

# %%
police.country_name.isnull().sum()
# Out:
# 65535

# %%
police.dropna(axis=1,thresh=60000,inplace=True)

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02      1:55             M          1985.0        20.0       White
# 1 2005-01-18      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome is_arrested  \
# 0      Speeding  Speeding             False     Citation       False
# 1      Speeding  Speeding             False     Citation       False
#
#   stop_duration  drugs_related_stop
# 0      0-15 Min               False
# 1      0-15 Min               False

# %% [markdown]
# ### driver_gender

# %%
police.driver_gender.value_counts(dropna=False)
# Out:
# M      45164
# F      16310
# NaN     4061
# Name: driver_gender, dtype: int64

# %%
print(45164+16310+4061)
# Out:
# 65535

# %%
print(police['driver_gender'].dtype)
# Out:
# object

# %%
police.driver_gender.isnull().sum()
# Out:
# 4061

# %%
# pd.options.display.max_rows = 4062

# %%
police[police['driver_gender'].isnull()]
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 25    2005-09-03     16:02           NaN             NaN         NaN
# 29    2005-09-26      1:05           NaN             NaN         NaN
# 52    2005-10-01     13:09           NaN             NaN         NaN
# 110   2005-10-03     19:50           NaN             NaN         NaN
# 124   2005-10-04     11:43           NaN             NaN         NaN
# ...          ...       ...           ...             ...         ...
# 65427 2012-12-02      3:23           NaN             NaN         NaN
# 65488 2012-12-05      8:35           NaN             NaN         NaN
# 65493 2012-12-05     13:20           NaN             NaN         NaN
# 65502 2012-12-05     23:57           NaN             NaN         NaN
# 65533 2012-12-07      0:23           NaN             NaN         NaN
#
#       driver_race violation_raw violation  search_conducted stop_outcome  \
# ...

# %%
import numpy as np

# %%
police.driver_gender.replace(to_replace=np.nan,value='M',inplace=True)

# %%
police[police['driver_gender'].isnull()]
# Out:
# Empty DataFrame
# Columns: [stop_date, stop_time, driver_gender, driver_age_raw, driver_age, driver_race, violation_raw, violation, search_conducted, stop_outcome, is_arrested, stop_duration, drugs_related_stop]
# Index: []

# %%
police.driver_gender.value_counts()
# Out:
# M    49225
# F    16310
# Name: driver_gender, dtype: int64

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02      1:55             M          1985.0        20.0       White
# 1 2005-01-18      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome is_arrested  \
# 0      Speeding  Speeding             False     Citation       False
# 1      Speeding  Speeding             False     Citation       False
#
#   stop_duration  drugs_related_stop
# 0      0-15 Min               False
# 1      0-15 Min               False

# %% [markdown]
# ### driver_age_raw

# %%
police.driver_age_raw.value_counts(dropna=False)
# Out:
# NaN       4054
# 1986.0    2702
# 1987.0    2645
# 1985.0    2630
# 1988.0    2588
#           ...
# 1918.0       1
# 8801.0       1
# 2919.0       1
# 1887.0       1
# 2002.0       1
# Name: driver_age_raw, Length: 94, dtype: int64

# %%
police.driver_age_raw.isnull().sum()
# Out:
# 4054

# %%
print(police['driver_age_raw'].dtype)
# Out:
# float64

# %%
pd.options.display.max_rows = 10000

# %%
police[police['driver_age_raw']<1900].head(2)
# Out:
#      stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 146 2005-10-05      8:50             M             0.0         NaN
# 281 2005-10-10     12:05             F             0.0         NaN
#
#     driver_race            violation_raw         violation  search_conducted  \
# 146       White  Other Traffic Violation  Moving violation             False
# 281       White  Other Traffic Violation  Moving violation             False
#
#     stop_outcome is_arrested stop_duration  drugs_related_stop
# 146     Citation       False      0-15 Min               False
# 281      Warning       False      0-15 Min               False

# %%
police[police['driver_age_raw']==1968].shape
# Out:
# (1146, 13)

# %%
police['driver_age_raw'].mean()
# Out:
# 1967.79110619541

# %%
mean=round(police.driver_age_raw.mean(),0)
mean
# Out:
# 1968.0

# %%
police.driver_age_raw.fillna(mean,inplace=True)

# %%
police.driver_age_raw.value_counts(dropna=False).head()
# Out:
# 1968.0    5200
# 1986.0    2702
# 1987.0    2645
# 1985.0    2630
# 1988.0    2588
# Name: driver_age_raw, dtype: int64

# %%
police[police['driver_age_raw']==1968].shape
# Out:
# (5200, 13)

# %%
police[police['driver_age_raw']==0].shape
# Out:
# (217, 13)

# %%
police.driver_age_raw.replace(to_replace=0,value=1985,inplace=True)

# %%
police[police['driver_age_raw']==0]
# Out:
# Empty DataFrame
# Columns: [stop_date, stop_time, driver_gender, driver_age_raw, driver_age, driver_race, violation_raw, violation, search_conducted, stop_outcome, is_arrested, stop_duration, drugs_related_stop]
# Index: []

# %%
police.driver_age_raw.unique()
# Out:
# array([1985., 1965., 1972., 1986., 1984., 1982., 1969., 1970., 1979.,
#        1966., 1955., 1958., 1953., 1967., 1968., 1964., 1977., 1959.,
#        1973., 1947., 1978., 1962., 1981., 1988., 1983., 1961., 1957.,
#        1971., 1950., 1954., 1960., 1976., 1974., 1938., 1980., 1963.,
#        1975., 1987., 1948., 1956., 1944., 1935., 1952., 1945., 1946.,
#        1941., 1942., 1951., 1949., 2005., 1939., 1943., 1936., 1924.,
#        1937., 1929., 1930., 1931., 1923., 1940., 1933., 1989., 1928.,
#        1932., 1990., 1926., 2006., 1927., 1997., 1934., 1887., 1925.,
#        1918., 2004., 1991., 2002., 2007., 1992., 8801., 2001., 2003.,
#        1998., 1922., 1993., 2008., 2009., 2919., 2000., 1994., 1995.,
#        2011., 1996.])

# %%
police[police['driver_age_raw']==2919]
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 37779 2009-10-10      8:23             F          2919.0         NaN
#
#       driver_race violation_raw violation  search_conducted stop_outcome  \
# 37779       White      Speeding  Speeding             False     Citation
#
#       is_arrested stop_duration  drugs_related_stop
# 37779       False      0-15 Min               False

# %%
police[police['driver_age_raw']==8801]
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 17964 2007-06-17      9:55             M          8801.0         NaN
#
#       driver_race violation_raw violation  search_conducted stop_outcome  \
# 17964       White      Speeding  Speeding             False     Citation
#
#       is_arrested stop_duration  drugs_related_stop
# 17964       False     16-30 Min               False

# %%
police.drop(index=[37779,17964],inplace=True)

# %%
police[police['driver_age_raw']==8801]
# Out:
# Empty DataFrame
# Columns: [stop_date, stop_time, driver_gender, driver_age_raw, driver_age, driver_race, violation_raw, violation, search_conducted, stop_outcome, is_arrested, stop_duration, drugs_related_stop]
# Index: []

# %%
police[police['driver_age_raw']==2919]
# Out:
# Empty DataFrame
# Columns: [stop_date, stop_time, driver_gender, driver_age_raw, driver_age, driver_race, violation_raw, violation, search_conducted, stop_outcome, is_arrested, stop_duration, drugs_related_stop]
# Index: []

# %%
police.driver_age_raw.describe()
# Out:
# count    65533.000000
# mean      1974.258191
# std         12.556791
# min       1887.000000
# 25%       1966.000000
# 50%       1977.000000
# 75%       1985.000000
# max       2011.000000
# Name: driver_age_raw, dtype: float64

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02      1:55             M          1985.0        20.0       White
# 1 2005-01-18      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome is_arrested  \
# 0      Speeding  Speeding             False     Citation       False
# 1      Speeding  Speeding             False     Citation       False
#
#   stop_duration  drugs_related_stop
# 0      0-15 Min               False
# 1      0-15 Min               False

# %% [markdown]
# ### driver_age

# %%
police.driver_age.value_counts(dropna=False).head(2)
# Out:
# NaN     4305
# 22.0    2912
# Name: driver_age, dtype: int64

# %%
print(police['driver_age'].dtype)
# Out:
# float64

# %%
police.driver_age.isnull().sum()
# Out:
# 4305

# %%
police.driver_age.mean()
# Out:
# 34.14898412491017

# %%
mean= round(police.driver_age.mean(),0)
mean
# Out:
# 34.0

# %%
police.driver_age.fillna(mean,inplace=True)

# %%
police.driver_age.isnull().sum()
# Out:
# 0

# %%
police.driver_age.unique()
# Out:
# array([20., 40., 33., 19., 21., 23., 36., 35., 26., 39., 50., 47., 52.,
#        38., 34., 41., 28., 46., 32., 58., 27., 43., 24., 17., 22., 44.,
#        48., 55., 51., 45., 29., 31., 37., 67., 25., 42., 30., 18., 57.,
#        49., 61., 70., 53., 60., 59., 64., 63., 54., 56., 66., 62., 69.,
#        81., 68., 76., 75., 74., 82., 65., 72., 16., 77., 73., 71., 80.,
#        79., 78., 88., 15., 83., 86., 84., 85.])

# %%
police.driver_age.describe()
# Out:
# count    65533.000000
# mean        34.139197
# std         12.334501
# min         15.000000
# 25%         24.000000
# 50%         32.000000
# 75%         42.000000
# max         88.000000
# Name: driver_age, dtype: float64

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02      1:55             M          1985.0        20.0       White
# 1 2005-01-18      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome is_arrested  \
# 0      Speeding  Speeding             False     Citation       False
# 1      Speeding  Speeding             False     Citation       False
#
#   stop_duration  drugs_related_stop
# 0      0-15 Min               False
# 1      0-15 Min               False

# %% [markdown]
# ### driver_race

# %%
police.driver_race.value_counts(dropna=False)
# Out:
# White       45745
# Black        8267
# Hispanic     5611
# NaN          4060
# Asian        1639
# Other         211
# Name: driver_race, dtype: int64

# %%
print(police['driver_race'].dtype)
# Out:
# object

# %%
police.driver_race.isnull().sum()
# Out:
# 4060

# %%
police.driver_race.replace(to_replace=np.nan,value='Other',inplace=True)

# %%
police.driver_race.isnull().sum()
# Out:
# 0

# %%
police.driver_race.value_counts(dropna=False)
# Out:
# White       45745
# Black        8267
# Hispanic     5611
# Other        4271
# Asian        1639
# Name: driver_race, dtype: int64

# %%
police[police['driver_race']=='Other'].head(1)
# Out:
#     stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 25 2005-09-03     16:02             M          1968.0        34.0       Other
#
#    violation_raw violation  search_conducted stop_outcome is_arrested  \
# 25           NaN       NaN             False          NaN         NaN
#
#    stop_duration  drugs_related_stop
# 25           NaN               False

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02      1:55             M          1985.0        20.0       White
# 1 2005-01-18      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome is_arrested  \
# 0      Speeding  Speeding             False     Citation       False
# 1      Speeding  Speeding             False     Citation       False
#
#   stop_duration  drugs_related_stop
# 0      0-15 Min               False
# 1      0-15 Min               False

# %% [markdown]
# ### violation_raw

# %%
police.violation_raw.value_counts(dropna=False)
# Out:
# Speeding                            37202
# Other Traffic Violation             11926
# Equipment/Inspection Violation       6516
# NaN                                  4060
# Special Detail/Directed Patrol       2383
# Registration Violation               2243
# Call for Service                      793
# Violation of City/Town Ordinance      170
# Motorist Assist/Courtesy              138
# APB                                    51
# Suspicious Person                      38
# Warrant                                10
# Seatbelt Violation                      3
# Name: violation_raw, dtype: int64

# %%
print(police['violation_raw'].dtype)
# Out:
# object

# %%
police.violation_raw.isnull().sum()
# Out:
# 4060

# %%
# police.violation_raw.replace(to_replace=np.nan,value='Other Traffic Violation',inplace=True)

# %%
police.violation_raw.fillna(method='ffill',inplace=True)

# %%
police.violation_raw.isnull().sum()
# Out:
# 0

# %%
police.violation_raw.value_counts(dropna=False)
# Out:
# Speeding                            39465
# Other Traffic Violation             12798
# Equipment/Inspection Violation       6972
# Special Detail/Directed Patrol       2557
# Registration Violation               2427
# Call for Service                      875
# Violation of City/Town Ordinance      178
# Motorist Assist/Courtesy              150
# APB                                    56
# Suspicious Person                      39
# Warrant                                13
# Seatbelt Violation                      3
# Name: violation_raw, dtype: int64

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02      1:55             M          1985.0        20.0       White
# 1 2005-01-18      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome is_arrested  \
# 0      Speeding  Speeding             False     Citation       False
# 1      Speeding  Speeding             False     Citation       False
#
#   stop_duration  drugs_related_stop
# 0      0-15 Min               False
# 1      0-15 Min               False

# %% [markdown]
# ### violation

# %%
police.violation.value_counts(dropna=False)
# Out:
# Speeding               37202
# Moving violation       11926
# Equipment               6516
# NaN                     4060
# Other                   3583
# Registration/plates     2243
# Seat belt                  3
# Name: violation, dtype: int64

# %%
print(police.iloc[:,7].dtype)
# Out:
# object

# %%
police.violation.isnull().sum()
# Out:
# 4060

# %%
police.violation.fillna(method='bfill',inplace=True)

# %%
police.violation.isnull().sum()
# Out:
# 0

# %%
police.violation.value_counts(dropna=False)
# Out:
# Speeding               39521
# Moving violation       12802
# Equipment               6927
# Other                   3848
# Registration/plates     2432
# Seat belt                  3
# Name: violation, dtype: int64

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02      1:55             M          1985.0        20.0       White
# 1 2005-01-18      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome is_arrested  \
# 0      Speeding  Speeding             False     Citation       False
# 1      Speeding  Speeding             False     Citation       False
#
#   stop_duration  drugs_related_stop
# 0      0-15 Min               False
# 1      0-15 Min               False

# %% [markdown]
# ### search_conducated

# %%
police.search_conducted.value_counts()
# Out:
# False    63054
# True      2479
# Name: search_conducted, dtype: int64

# %%
print(police['search_conducted'].dtype)
# Out:
# bool

# %%
police.search_conducted.isnull().sum()
# Out:
# 0

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02      1:55             M          1985.0        20.0       White
# 1 2005-01-18      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome is_arrested  \
# 0      Speeding  Speeding             False     Citation       False
# 1      Speeding  Speeding             False     Citation       False
#
#   stop_duration  drugs_related_stop
# 0      0-15 Min               False
# 1      0-15 Min               False

# %% [markdown]
# ### stop_outcome

# %%
police.stop_outcome.value_counts(dropna=False)
# Out:
# Citation            56562
# NaN                  4060
# Arrest Driver        2009
# Warning              1889
# N/D                   423
# No Action             339
# Arrest Passenger      251
# Name: stop_outcome, dtype: int64

# %%
print(police['stop_outcome'].dtype)
# Out:
# object

# %%
police.stop_outcome.isnull().sum()
# Out:
# 4060

# %%
police.stop_outcome.fillna(method='ffill',inplace=True)

# %%
police.stop_outcome.isnull().sum()
# Out:
# 0

# %%
police.stop_outcome.value_counts(dropna=False)
# Out:
# Citation            60163
# Arrest Driver        2270
# Warning              2009
# N/D                   447
# No Action             370
# Arrest Passenger      274
# Name: stop_outcome, dtype: int64

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02      1:55             M          1985.0        20.0       White
# 1 2005-01-18      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome is_arrested  \
# 0      Speeding  Speeding             False     Citation       False
# 1      Speeding  Speeding             False     Citation       False
#
#   stop_duration  drugs_related_stop
# 0      0-15 Min               False
# 1      0-15 Min               False

# %% [markdown]
# ### is_arrested

# %%
police.is_arrested.value_counts()
# Out:
# False    59213
# True      2260
# Name: is_arrested, dtype: int64

# %%
print(police['is_arrested'].dtype)
# Out:
# object

# %%
police.is_arrested= police.is_arrested.astype('bool')

# %%
print(police['is_arrested'].dtype)
# Out:
# bool

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02      1:55             M          1985.0        20.0       White
# 1 2005-01-18      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome  is_arrested  \
# 0      Speeding  Speeding             False     Citation        False
# 1      Speeding  Speeding             False     Citation        False
#
#   stop_duration  drugs_related_stop
# 0      0-15 Min               False
# 1      0-15 Min               False

# %% [markdown]
# ### stop_duration

# %%
police.stop_duration.value_counts()
# Out:
# 0-15 Min     47378
# 16-30 Min    11447
# 30+ Min       2647
# 2                1
# Name: stop_duration, dtype: int64

# %%
print(police['stop_duration'].dtype)
# Out:
# object

# %%
police.stop_duration.replace(to_replace=['0-15 Min','16-30 Min','30+ Min','2'],value=['7.5','24','45','45'],inplace=True)

# %%
police.stop_duration.value_counts()
# Out:
# 7.5    47378
# 24     11447
# 45      2648
# Name: stop_duration, dtype: int64

# %%
police.stop_duration=police.stop_duration.astype('float')

# %%
print(police['stop_duration'].dtype)
# Out:
# float64

# %%
police.stop_duration.isnull().sum()
# Out:
# 4060

# %%
police.stop_duration.mean()
# Out:
# 12.187838563271681

# %%
mean=round(police.stop_duration.mean(),0)
mean
# Out:
# 12.0

# %%
# police.stop_duration.fillna(mean,inplace=True)

# %%
police.stop_duration.replace(to_replace=np.nan,value=7.5,inplace=True)

# %%
police.stop_duration.isnull().sum()
# Out:
# 0

# %%
police.stop_duration.value_counts()
# Out:
# 7.5     51438
# 24.0    11447
# 45.0     2648
# Name: stop_duration, dtype: int64

# %%
police.stop_duration.describe()
# Out:
# count    65533.00000
# mean        11.89741
# std          9.22182
# min          7.50000
# 25%          7.50000
# 50%          7.50000
# 75%          7.50000
# max         45.00000
# Name: stop_duration, dtype: float64

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02      1:55             M          1985.0        20.0       White
# 1 2005-01-18      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome  is_arrested  \
# 0      Speeding  Speeding             False     Citation        False
# 1      Speeding  Speeding             False     Citation        False
#
#    stop_duration  drugs_related_stop
# 0            7.5               False
# 1            7.5               False

# %% [markdown]
# ### drugs_related_stop

# %%
police.drugs_related_stop.value_counts()
# Out:
# False    65015
# True       518
# Name: drugs_related_stop, dtype: int64

# %%
print(police.iloc[:,12].dtype)
# Out:
# bool

# %%
police.iloc[:,12].isnull().sum()
# Out:
# 0

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02      1:55             M          1985.0        20.0       White
# 1 2005-01-18      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome  is_arrested  \
# 0      Speeding  Speeding             False     Citation        False
# 1      Speeding  Speeding             False     Citation        False
#
#    stop_duration  drugs_related_stop
# 0            7.5               False
# 1            7.5               False

# %% [markdown]
# ### Duplicate Value

# %%
police[police.duplicated(keep='first')]
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 16    2005-07-19      0:30             M          1982.0        23.0
# 104   2005-10-03     13:26             M          1975.0        30.0
# 117   2005-10-04      0:36             M          1961.0        44.0
# 149   2005-10-05     10:00             M          1981.0        24.0
# 239   2005-10-08     12:30             M          1978.0        27.0
# 257   2005-10-09     13:00             M          1963.0        42.0
# 330   2005-10-12      7:30             M          1965.0        40.0
# 340   2005-10-12     20:30             M          1987.0        18.0
# 509   2005-10-21      1:15             M          1982.0        23.0
# 592   2005-10-23     15:00             M          1954.0        51.0
# 813   2005-10-30     11:45             M          1980.0        25.0
# 900   2005-11-02      1:45             F          1987.0        18.0
# 1039  2005-11-05     17:05             M          1968.0        34.0
# ...

# %%
# duplicate data
police.iloc[15:17]
# Out:
#     stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 15 2005-07-19      0:30             M          1982.0        23.0       White
# 16 2005-07-19      0:30             M          1982.0        23.0       White
#
#    violation_raw violation  search_conducted stop_outcome  is_arrested  \
# 15      Speeding  Speeding             False     Citation        False
# 16      Speeding  Speeding             False     Citation        False
#
#     stop_duration  drugs_related_stop
# 15            7.5               False
# 16            7.5               False

# %%
police.drop_duplicates(keep='first',inplace=True)

# %%
police[police.duplicated(keep='first')]
# Out:
# Empty DataFrame
# Columns: [stop_date, stop_time, driver_gender, driver_age_raw, driver_age, driver_race, violation_raw, violation, search_conducted, stop_outcome, is_arrested, stop_duration, drugs_related_stop]
# Index: []

# %%
police.shape
# Out:
# (65213, 13)

# %%
police.count()
# Out:
# stop_date             65213
# stop_time             65213
# driver_gender         65213
# driver_age_raw        65213
# driver_age            65213
# driver_race           65213
# violation_raw         65213
# violation             65213
# search_conducted      65213
# stop_outcome          65213
# is_arrested           65213
# stop_duration         65213
# drugs_related_stop    65213
# dtype: int64

# %%
police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65213 entries, 0 to 65534
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65213 non-null  datetime64[ns]
#  1   stop_time           65213 non-null  object
#  2   driver_gender       65213 non-null  object
#  3   driver_age_raw      65213 non-null  float64
#  4   driver_age          65213 non-null  float64
#  5   driver_race         65213 non-null  object
#  6   violation_raw       65213 non-null  object
#  7   violation           65213 non-null  object
#  8   search_conducted    65213 non-null  bool
#  9   stop_outcome        65213 non-null  object
#  10  is_arrested         65213 non-null  bool
#  11  stop_duration       65213 non-null  float64
#  12  drugs_related_stop  65213 non-null  bool
# dtypes: bool(3), datetime64[ns](1), float64(3), object(6)
# memory usage: 5.7+ MB

# %%
police.describe()
# Out:
#        driver_age_raw    driver_age  stop_duration
# count    65213.000000  65213.000000   65213.000000
# mean      1974.268643     34.145584      11.894377
# std         12.569930     12.349191       9.213956
# min       1887.000000     15.000000       7.500000
# 25%       1966.000000     24.000000       7.500000
# 50%       1977.000000     32.000000       7.500000
# 75%       1985.000000     42.000000       7.500000
# max       2011.000000     88.000000      45.000000

# %% [markdown]
# ### Iterate Year from stop_date column

# %%
police['Year'] = police['stop_date'].dt.year

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02      1:55             M          1985.0        20.0       White
# 1 2005-01-18      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome  is_arrested  \
# 0      Speeding  Speeding             False     Citation        False
# 1      Speeding  Speeding             False     Citation        False
#
#    stop_duration  drugs_related_stop  Year
# 0            7.5               False  2005
# 1            7.5               False  2005

# %% [markdown]
# ### Year

# %%
police.Year.value_counts()
# Out:
# 2006    10576
# 2012    10490
# 2007     9387
# 2008     8709
# 2011     8100
# 2009     7878
# 2010     7540
# 2005     2533
# Name: Year, dtype: int64

# %%
police.iloc[:,13].isnull().sum()
# Out:
# 0

# %%
print(police['Year'].dtype)
# Out:
# int64

# %% [markdown]
# ## Data Analysis

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02      1:55             M          1985.0        20.0       White
# 1 2005-01-18      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted stop_outcome  is_arrested  \
# 0      Speeding  Speeding             False     Citation        False
# 1      Speeding  Speeding             False     Citation        False
#
#    stop_duration  drugs_related_stop  Year
# 0            7.5               False  2005
# 1            7.5               False  2005

# %%
police[police.iloc[:,7]=='Speeding'].shape
# Out:
# (39347, 14)

# %%
police.iloc[:,6].unique()
# Out:
# array(['Speeding', 'Call for Service', 'Equipment/Inspection Violation',
#        'Other Traffic Violation', 'Registration Violation',
#        'Special Detail/Directed Patrol', 'APB',
#        'Violation of City/Town Ordinance', 'Suspicious Person',
#        'Motorist Assist/Courtesy', 'Warrant', 'Seatbelt Violation'],
#       dtype=object)
