# %%
import pandas as pd

# %%
titanic= pd.read_csv('titanic_raw.csv')

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.min_rows
# Out:
# 10

# %%
pd.options.display.max_columns
# Out:
# 20

# %%
pd.options.display.max_rows = 900

# %%
titanic
# Out:
#                                                    This       is        the  \
# It   contains  all       passengers  that          were   aboard        the
# the  tragic    disaster  occured     in             the     year         19
# 0   0         3         male        22.0              1        0      $7.25
# 1   1         1         female      38.0              1        0   $71.2833
# 2   1         3         female      26.0              0        0     $7.925
# 3   1         1         female      35.0              1        0      $53.1
# 4   0         3         male        35.0              0        0      $8.05
# 5   0         3         male        Missing Data      0        0    $8.4583
# 6   0         1         male        54.0              0        0   $51.8625
# 7   0         3         male        2.0               3        1    $21.075
# 8   1         3         female      27.0              0        2   $11.1333
# ...

# %%
col_names=["survived","Class","Gender","Age","SipSp","ParCh","Fare","Emb","Deck"]

# %%
titanic= pd.read_csv('titanic_raw.csv',header=None,skiprows=3,skipfooter=2,names= col_names)
# Out:
# <ipython-input-9-d66bc95121f5>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   titanic= pd.read_csv('titanic_raw.csv',header=None,skiprows=3,skipfooter=2,names= col_names)

# %%
titanic
# Out:
#     survived  Class  Gender           Age  SipSp  ParCh       Fare  Emb Deck
# 0          0      3    male          22.0      1      0      $7.25    S  NaN
# 1          1      1  female          38.0      1      0   $71.2833    C    C
# 2          1      3  female          26.0      0      0     $7.925    S  NaN
# 3          1      1  female          35.0      1      0      $53.1    S    C
# 4          0      3    male          35.0      0      0      $8.05    S  NaN
# 5          0      3    male  Missing Data      0      0    $8.4583    Q  NaN
# 6          0      1    male          54.0      0      0   $51.8625    S    E
# 7          0      3    male           2.0      3      1    $21.075    S  NaN
# 8          1      3  female          27.0      0      2   $11.1333    S  NaN
# 9          1      2  female          14.0      1      0   $30.0708    C  NaN
# 10         1      3  female           4.0      1      1      $16.7    S    G
# ...

# %%
titanic.shape
# Out:
# (894, 9)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 894 entries, 0 to 893
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  894 non-null    object
#  1   Class     894 non-null    int64
#  2   Gender    894 non-null    object
#  3   Age       758 non-null    object
#  4   SipSp     894 non-null    int64
#  5   ParCh     894 non-null    int64
#  6   Fare      894 non-null    object
#  7   Emb       892 non-null    object
#  8   Deck      203 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 69.8+ KB

# %%
titanic.isnull().sum()
# Out:
# survived      0
# Class         0
# Gender        0
# Age         136
# SipSp         0
# ParCh         0
# Fare          0
# Emb           2
# Deck        691
# dtype: int64

# %%
titanic.survived.value_counts()
# Out:
# 0      551
# 1      341
# yes      1
# no       1
# Name: survived, dtype: int64

# %%
titanic.survived.replace(to_replace=['yes','no'],value=[1,0],inplace =True)

# %%
titanic.survived.value_counts()
# Out:
# 0    551
# 1    341
# 0      1
# 1      1
# Name: survived, dtype: int64

# %%
titanic.survived= titanic.survived.astype('int')

# %%
titanic.Class.value_counts()
# Out:
# 3    493
# 1    216
# 2    185
# Name: Class, dtype: int64

# %%
titanic.Gender.value_counts()
# Out:
# male      580
# female    314
# Name: Gender, dtype: int64

# %%
titanic.Age.value_counts(dropna=False).head()
# Out:
# NaN             136
# Missing Data     41
# 24.0             31
# 22.0             27
# 18.0             26
# Name: Age, dtype: int64

# %%
import numpy as np

# %%
titanic.Age.replace(to_replace='Missing Data',value=np.nan,inplace =True)

# %%
titanic.Age.value_counts(dropna=False).head()
# Out:
# NaN     177
# 24.0     31
# 22.0     27
# 18.0     26
# 30.0     25
# Name: Age, dtype: int64

# %%
titanic.Age=titanic.Age.astype('float')

# %%
titanic.Age.mean()
# Out:
# 30.718507670850766

# %%
mean=round(titanic.Age.mean(),1)

# %%
titanic.Age.fillna(mean,inplace=True)

# %%
titanic.SipSp.value_counts()
# Out:
# 0    610
# 1    210
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SipSp, dtype: int64

# %%
titanic.ParCh.value_counts()
# Out:
# 0    680
# 1    119
# 2     80
# 3      5
# 5      5
# 4      4
# 6      1
# Name: ParCh, dtype: int64

# %%
titanic.Fare.value_counts().head()
# Out:
# $8.05      43
# $13.0      42
# $7.8958    39
# $7.75      34
# $26.0      31
# Name: Fare, dtype: int64

# %%
titanic.Fare=titanic.Fare.str.replace("$","")
# Out:
# <ipython-input-31-ca2ef5adecb5>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   titanic.Fare=titanic.Fare.str.replace("$","")

# %%
titanic.Fare.head(2)
# Out:
# 0       7.25
# 1    71.2833
# Name: Fare, dtype: object

# %%
titanic.Fare=titanic.Fare.astype('float')

# %%
titanic.head(2)
# Out:
#    survived  Class  Gender   Age  SipSp  ParCh     Fare Emb Deck
# 0         0      3    male  22.0      1      0   7.2500   S  NaN
# 1         1      1  female  38.0      1      0  71.2833   C    C

# %%
titanic.Emb.value_counts()
# Out:
# S    647
# C    168
# Q     77
# Name: Emb, dtype: int64

# %%
titanic.Deck.value_counts(dropna=False)
# Out:
# NaN    691
# C       59
# B       47
# D       33
# E       32
# A       15
# F       13
# G        4
# Name: Deck, dtype: int64

# %%
titanic.dropna(axis=1,thresh=500,inplace=True)

# %%
titanic.fillna(method='ffill',inplace=True)

# %%
titanic.shape
# Out:
# (894, 8)

# %%
titanic[titanic.duplicated(keep='first')]
# Out:
#      survived  Class  Gender    Age  SipSp  ParCh     Fare Emb
# 47          1      3  female  30.70      0      0   7.7500   Q
# 76          0      3    male  30.70      0      0   7.8958   S
# 77          0      3    male  30.70      0      0   8.0500   S
# 87          0      3    male  30.70      0      0   8.0500   S
# 95          0      3    male  30.70      0      0   8.0500   S
# 101         0      3    male  30.70      0      0   7.8958   S
# 121         0      3    male  30.70      0      0   8.0500   S
# 133         1      2  female  29.00      1      0  26.0000   S
# 173         0      3    male  21.00      0      0   7.9250   S
# 196         0      3    male  30.70      0      0   7.7500   Q
# 198         1      3  female  30.70      0      0   7.7500   Q
# 201         0      3    male  30.70      8      2  69.5500   S
# 213         0      2    male  30.00      0      0  13.0000   S
# 223         0      3    male  30.70      0      0   7.8958   S
# ...

# %%
# titanic.drop_duplicates(keep='first',inplace=True)

# %%
# titanic.shape

# %%
# titanic[titanic.duplicated(keep='first')]

# %%
titanic.head(2)
# Out:
#    survived  Class  Gender   Age  SipSp  ParCh     Fare Emb
# 0         0      3    male  22.0      1      0   7.2500   S
# 1         1      1  female  38.0      1      0  71.2833   C

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 894 entries, 0 to 893
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  894 non-null    int32
#  1   Class     894 non-null    int64
#  2   Gender    894 non-null    object
#  3   Age       894 non-null    float64
#  4   SipSp     894 non-null    int64
#  5   ParCh     894 non-null    int64
#  6   Fare      894 non-null    float64
#  7   Emb       894 non-null    object
# dtypes: float64(2), int32(1), int64(3), object(2)
# memory usage: 59.4+ KB

# %%
titanic.describe()
# Out:
#          survived       Class         Age       SipSp       ParCh        Fare
# count  894.000000  894.000000  894.000000  894.000000  894.000000  894.000000
# mean     0.382550    2.309843   30.714843    0.522371    0.381432   32.132824
# std      0.486282    0.835370   21.554721    1.101283    0.805171   49.625396
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.903100
# 50%      0.000000    3.000000   30.700000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000  490.000000    8.000000    6.000000  512.329200

# %%
titanic.isnull().sum()
# Out:
# survived    0
# Class       0
# Gender      0
# Age         0
# SipSp       0
# ParCh       0
# Fare        0
# Emb         0
# dtype: int64

# %%
titanic.count()
# Out:
# survived    894
# Class       894
# Gender      894
# Age         894
# SipSp       894
# ParCh       894
# Fare        894
# Emb         894
# dtype: int64

# %% [markdown]
# ## Data Analytics

# %%
titanic.head(2)
# Out:
#    survived  Class  Gender   Age  SipSp  ParCh     Fare Emb
# 0         0      3    male  22.0      1      0   7.2500   S
# 1         1      1  female  38.0      1      0  71.2833   C

# %%
titanic['Gender'].value_counts()
# Out:
# male      580
# female    314
# Name: Gender, dtype: int64

# %%
titanic[titanic['Gender']=='male'].shape
# Out:
# (580, 8)

# %%
titanic[(titanic['Gender']=='male') & (titanic['Age'] > 70)]
# Out:
#      survived  Class Gender    Age  SipSp  ParCh     Fare Emb
# 96          0      1   male   71.0      0      0  34.6542   C
# 116         0      3   male   70.5      0      0   7.7500   Q
# 217         0      2   male  102.0      1      0  27.0000   S
# 453         1      1   male  490.0      1      0  89.1042   C
# 493         0      1   male   71.0      0      0  49.5042   C
# 630         1      1   male   80.0      0      0  30.0000   S
# 785         0      3   male  250.0      0      0   7.2500   S
# 851         0      3   male   74.0      0      0   7.7750   S

# %%
titanic['Age'].mean()
# Out:
# 30.714843400447425

# %%
titanic.iloc[:,3].mean()
# Out:
# 30.714843400447425

# %%
titanic.iloc[:,3].median()
# Out:
# 30.7

# %%
titanic.iloc[:,3].mode()
# Out:
# 0    30.7
# dtype: float64

# %%
titanic.iloc[:,3].max()
# Out:
# 490.0

# %%
titanic.iloc[:,3].min()
# Out:
# 0.42

# %%
# Age above 80
titanic[titanic.iloc[:,3] >80]
# Out:
#      survived  Class Gender    Age  SipSp  ParCh     Fare Emb
# 217         0      2   male  102.0      1      0  27.0000   S
# 453         1      1   male  490.0      1      0  89.1042   C
# 785         0      3   male  250.0      0      0   7.2500   S

# %%
titanic.drop(index=[217,453,785],inplace=True)

# %%
titanic.shape
# Out:
# (891, 8)

# %%
titanic[(titanic.iloc[:,6] <50) & (titanic.iloc[:,1] == 1)]
# Out:
#      survived  Class  Gender   Age  SipSp  ParCh     Fare Emb
# 11          1      1  female  58.0      0      0  26.5500   S
# 23          1      1    male  28.0      0      0  35.5000   S
# 30          0      1    male  40.0      0      0  27.7208   C
# 55          1      1    male  30.7      0      0  35.5000   S
# 64          0      1    male  30.7      0      0  27.7208   C
# 83          0      1    male  28.0      0      0  47.1000   S
# 96          0      1    male  71.0      0      0  34.6542   C
# 136         1      1  female  19.0      0      2  26.2833   S
# 168         0      1    male  30.7      0      0  25.9250   S
# 170         0      1    male  61.0      0      0  33.5000   S
# 174         0      1    male  56.0      0      0  30.6958   C
# 177         0      1  female  50.0      0      0  28.7125   C
# 187         1      1    male  45.0      0      0  26.5500   S
# 194         1      1  female  44.0      0      0  27.7208   C
# ...
